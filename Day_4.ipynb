# %%
x = input("Enter yhe name of a student")
a = int(input("Enter the marks scored in english"))
b = int(input("Enter the marks scored in hindi"))
c = int(input("Enter the marks scored in maths"))
d = int(input("Enter the marks scored in science"))
e = int(input("Enter the marks scored in social"))
n = ((a+b+c+d+e)/500)*100
print("The percent scored by student is ", n)
# Out:
# Enter yhe name of a student Pankaj
# Enter the marks scored in english 78
# Enter the marks scored in hindi 98
# Enter the marks scored in maths 89
# Enter the marks scored in science 76
# Enter the marks scored in social 75
# The percent scored by student is  83.2

# %%
a = int(input("enter the percetage scored by a student"))

if a>=90:
    print("A grade")
if a>=75  and a<90:
    print("B grade")
if a>=65 and a<75:
    print("C grade")
# Out:
# enter the percetage scored by a student 78
# B grade

# %%
a = int(input("enter the number"))
if a%5==0:
    print("hello")
else:
    print("bye")
# Out:
# enter the number 5
# hello

# %%
city = input("enter the city")
if city == "Delhi":
    print("The monument in Delhi is Redfort")
elif city == "Agra":
    print("The monument in Agra is Tajmahal")
elif city == "Jaipur":
    print("The monument in Jaipur is Jalmahal")
elif city == "Orissa":
    print("The monument in Orissa is konark Temple")
elif city == "Hyderabad":
    print("The monument in Hyderabad is Charminar")
else:
    print("No record fount")
# Out:
# enter the city Delhi
# The monument in Delhi is Redfort
